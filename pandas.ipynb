# %%
import pandas as pd

# %% [markdown]
# it provides 2 primary data structures series and datafram

# %%
#series

data = [1,2,3,4,5]
series = pd.Series(data)

series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#create a series from dictionary

data = {'a':1, 'b':2, 'c':3}
series_dict = pd.Series(data)
series_dict
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data, index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#dataframe
#create a dataframe from dictionary of list

data = {
    'Name':['Likhith','xyz','john'],
    'age':[21,22,23],
    'height':[5,6,7],
    'city':['us','eu','in']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  age  height city
# 0  Likhith   21       5   us
# 1      xyz   22       6   eu
# 2     john   23       7   in

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np
np.array(df)
# Out:
# array([['Likhith', 21, 5, 'us'],
#        ['xyz', 22, 6, 'eu'],
#        ['john', 23, 7, 'in']], dtype=object)

# %%
#create a data frame from list of dictionaries

data = [
    {'Name':'Likhith', 'Age':21, 'height':6, 'city':'us'},
    {'Name':'xyz', 'Age':22, 'height':5, 'city':'eu'},
    {'Name':'Jhon', 'Age':23, 'height':5, 'city':'in'},
]
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  height city
# 0  Likhith   21       6   us
# 1      xyz   22       5   eu
# 2     Jhon   23       5   in

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(type(df['Name']))
df['Name']
# Out:
# <class 'pandas.core.series.Series'>
# 0    Likhith
# 1        xyz
# 2       Jhon
# Name: Name, dtype: object

# %%
df.loc[0]
# Out:
# Name      Likhith
# Age            21
# height          6
# city           us
# Name: 0, dtype: object

# %%
df.iloc[1:]
# Out:
#    Name  Age  height city
# 1   xyz   22       5   eu
# 2  Jhon   23       5   in

# %%
df.at[1,'Age']
# Out:
# np.int64(22)

# %%
df.iat[2,2]
# Out:
# np.int64(5)

# %%
df['salary'] = [500000,400000,300000]
df
# Out:
#       Name  Age  height city  salary
# 0  Likhith   21       6   us  500000
# 1      xyz   22       5   eu  400000
# 2     Jhon   23       5   in  300000

# %%
df.drop('salary', axis = 1)
#doesnot save the state (temporary operation)
# Out:
#       Name  Age  height city
# 0  Likhith   21       6   us
# 1      xyz   22       5   eu
# 2     Jhon   23       5   in

# %%
df
# Out:
#       Name  Age  height city  salary
# 0  Likhith   21       6   us  500000
# 1      xyz   22       5   eu  400000
# 2     Jhon   23       5   in  300000

# %%
df.drop('salary', axis = 1, inplace = True)

# %%
df
# Out:
#       Name  Age  height city
# 0  Likhith   21       6   us
# 1      xyz   22       5   eu
# 2     Jhon   23       5   in

# %%
#add age
df['Age'] = df['Age'] + 1
df
# Out:
#       Name  Age  height city
# 0  Likhith   22       6   us
# 1      xyz   23       5   eu
# 2     Jhon   24       5   in

# %%
df.drop(0)
# Out:
#    Name  Age  height city
# 1   xyz   23       5   eu
# 2  Jhon   24       5   in

# %%
df
# Out:
#       Name  Age  height city
# 0  Likhith   22       6   us
# 1      xyz   23       5   eu
# 2     Jhon   24       5   in

# %%
url = "https://raw.githubusercontent.com/krishnaik06/Complete-Python-Bootcamp/main/10-Data%20Analysis%20With%20Python/sales_data.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.tail()
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# ...

# %%
df.loc[0]
# Out:
# Transaction ID              10001
# Date                   2024-01-01
# Product Category      Electronics
# Product Name        iPhone 14 Pro
# Units Sold                      2
# Unit Price                 999.99
# Total Revenue             1999.98
# Region              North America
# Payment Method        Credit Card
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Transaction ID              10001
# Date                   2024-01-01
# Product Category      Electronics
# Product Name        iPhone 14 Pro
# Units Sold                      2
# Unit Price                 999.99
# Total Revenue             1999.98
# Region              North America
# Payment Method        Credit Card
# Name: 0, dtype: object

# %%
df.dtypes
# Out:
# Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object

# %%
df.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000
